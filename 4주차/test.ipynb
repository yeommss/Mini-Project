# %%
import pandas as pd

# %%
df = pd.read_csv('범죄자_범행시_전과_여부_및_횟수_20220603105708.csv', encoding='cp949')
df.head()
# Out:
#   죄종별(1) 죄종별(2) 전과별(1) 전과별(2)     2011     2012     2013     2014     2015  \
# 0      계     소계      계     소계  1815233  1723815  1741302  1712435  1771390
# 1      계     소계     없음     소계   964589   431824   410041   401952   408411
# 2      계     소계   전과있음     소계   850644   836856   850657   826063   836002
# 3      계     소계   전과있음     1범   202925   199632   196926   190314   190438
# 4      계     소계   전과있음     2범   139392   134595   137263   132691   132073
#
#       2016     2017     2018     2019     2020
# 0  1847605  1685461  1581922  1585638  1494421
# 1   429304   391015   355589   359526   330824
# 2   873307   787453   709823   696593   655900
# 3   198122   178307   158147   153761   141663
# 4   137142   124017   108757   105304    96716

# %%
df.groupby(by=['죄종별(1)', '죄종별(2)']).count()
# Out:
#                     전과별(1)  전과별(2)  2011  2012  2013  2014  2015  2016  2017  \
# 죄종별(1) 죄종별(2)
# 강력범죄   강간               13      13    13    13    13    13    13    13    13
#        강간·강제추행          13      13    13    13    13    13    13    13    13
#        강도               13      13    13    13    13    13    13    13    13
#        강제추행             13      13    13    13    13    13    13    13    13
#        기타 강간·강제추행등      13      13    13    13    13    13    13    13    13
#        방화               13      13    13    13    13    13    13    13    13
#        살인기수             13      13    13    13    13    13    13    13    13
#        살인미수등            13      13    13    13    13    13    13    13    13
#        소계               13      13    13    13    13    13    13    13    13
#        유사강간             13      13    13    13    13    13    13    13    13
# 계      소계               13      13    13    13    13    13    13    13    13
# ...
