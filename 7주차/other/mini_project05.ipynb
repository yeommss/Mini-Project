# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('archive/insurance.csv')
df.shape
# Out:
# (1338, 7)

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df['age'].describe()
# Out:
# count    1338.000000
# mean       39.207025
# std        14.049960
# min        18.000000
# 25%        27.000000
# 50%        39.000000
# 75%        51.000000
# max        64.000000
# Name: age, dtype: float64

# %%
#30~50대가 많음
sns.boxplot(data=df, x='age')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
df['sex'].value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
sns.countplot(data=df,x='sex',hue='smoker')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
df['bmi'].describe()
# Out:
# count    1338.000000
# mean       30.663397
# std         6.098187
# min        15.960000
# 25%        26.296250
# 50%        30.400000
# 75%        34.693750
# max        53.130000
# Name: bmi, dtype: float64

# %%
#이상치 존재....? 애매하네
sns.boxplot(data=df, x='bmi')
# Out:
# <AxesSubplot:xlabel='bmi'>

# %%
df['children'].value_counts()
# Out:
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
df['children'].value_counts(normalize=True)
# Out:
# 0    0.428999
# 1    0.242152
# 2    0.179372
# 3    0.117339
# 4    0.018685
# 5    0.013453
# Name: children, dtype: float64

# %%
sns.countplot(data=df, x='children')
# Out:
# <AxesSubplot:xlabel='children', ylabel='count'>

# %%
df['smoker'].value_counts(normalize=True)
# Out:
# no     0.795217
# yes    0.204783
# Name: smoker, dtype: float64

# %%
df['region'].value_counts()
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
sns.scatterplot(data=df, x='age',y='bmi',hue='sex')
# Out:
# <AxesSubplot:xlabel='age', ylabel='bmi'>

# %%
df_smoker = df[df['smoker']=='yes']
sns.scatterplot(data=df_smoker, x='age',y='bmi',hue='smoker')
# Out:
# <AxesSubplot:xlabel='age', ylabel='bmi'>

# %%
sns.lineplot(data=df, x='age',y='bmi',hue='region', ci=None)
# Out:
# <AxesSubplot:xlabel='age', ylabel='bmi'>

# %%
#지역별 bmi 평균: southeast > southwest > northwest = northeast
df.groupby('region').mean()['bmi']
# Out:
# region
# northeast    29.173503
# northwest    29.199785
# southeast    33.355989
# southwest    30.596615
# Name: bmi, dtype: float64

# %%
label_name='charges'
label_name
# Out:
# 'charges'

# %%
feature_names = df.columns.to_list()
feature_names.remove(label_name)
feature_names
# Out:
# ['age', 'sex', 'bmi', 'children', 'smoker', 'region']
